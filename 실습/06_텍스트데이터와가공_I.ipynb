# %% [markdown]
# # 경로 및 다중 파일 처리
# ## os.getcwd, os.listdir

# %%
import os
import re
os.getcwd()
# Out:
# 'c:\\Users\\yunji\\Desktop\\코퍼스언어학\\실습'

# %%
os.listdir()
# Out:
# ['01_코퍼스와빅데이터.ipynb',
#  '02_Python_기초정리_I.ipynb',
#  '02_Python_기초정리_II.ipynb',
#  '03_Python_정규표현_01.ipynb',
#  '03_Python_정규표현_02.ipynb',
#  '04_Python_데이터분석구조_I.ipynb',
#  '04_Python_데이터분석구조_II.ipynb',
#  '05_마크업언어와문자코드.ipynb',
#  '06_data',
#  '06_out',
#  '06_텍스트데이터와가공_I.ipynb',
#  '06_텍스트데이터와가공_II.ipynb',
#  'data',
#  'txt']

# %% [markdown]
# ## os.chdir

# %%
os.chdir('c:\\Users\\yunji\\Desktop\\코퍼스언어학\\강의자료')
os.getcwd()
# Out:
# 'c:\\Users\\yunji\\Desktop\\코퍼스언어학\\강의자료'

# %%
os.listdir()
# Out:
# ['00_강의소개_코퍼스언어학.pdf',
#  '01_코퍼스와빅데이터.pdf',
#  '02_Python_기초정리_I.pdf',
#  '02_Python_기초정리_II.pdf',
#  '03_Python_정규표현_01.pdf',
#  '03_Python_정규표현_02.pdf',
#  '04_Python_데이터분석구조_I.pdf',
#  '04_Python_데이터분석구조_II.pdf',
#  '05_마크업언어와문자코드.pdf',
#  '06_data.zip',
#  '06_텍스트데이터와가공_I.pdf',
#  '06_텍스트데이터와가공_II.pdf',
#  '07_data.zip',
#  '07_텍스트데이터와빈도_I.pdf',
#  '07_텍스트데이터와빈도_II.pdf']

# %% [markdown]
# ## 상대 경로

# %%
os.listdir()
# Out:
# ['00_강의소개_코퍼스언어학.pdf',
#  '01_코퍼스와빅데이터.pdf',
#  '02_Python_기초정리_I.pdf',
#  '02_Python_기초정리_II.pdf',
#  '03_Python_정규표현_01.pdf',
#  '03_Python_정규표현_02.pdf',
#  '04_Python_데이터분석구조_I.pdf',
#  '04_Python_데이터분석구조_II.pdf',
#  '05_마크업언어와문자코드.pdf',
#  '06_data.zip',
#  '06_텍스트데이터와가공_I.pdf',
#  '06_텍스트데이터와가공_II.pdf',
#  '07_data.zip',
#  '07_텍스트데이터와빈도_I.pdf',
#  '07_텍스트데이터와빈도_II.pdf']

# %% [markdown]
# ## 연습문제 1
# (.zip은 없애놓았다고 가정)

# %%
os.chdir('c:\\Users\\yunji\\Desktop\\코퍼스언어학\\실습')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\yunji\\Desktop\\코퍼스언어학\\실습'

# %%
os.listdir('06_data/')
# Out:
# ['01.pdf',
#  '01.txt',
#  '02.pdf',
#  '02.txt',
#  '03.pdf',
#  '03.txt',
#  '04.pdf',
#  '04.txt']

# %%
[x for x in os.listdir('06_data/') if '.txt' in x] # 내 코드
# Out:
# ['01.txt', '02.txt', '03.txt', '04.txt']

# %%
[i for i in os.listdir('.\\06_data') if i.endswith('.txt')]
# Out:
# ['01.txt', '02.txt', '03.txt', '04.txt']

# %%
[i for i in os.listdir('06_data') if re.search('txt$', i)]
# Out:
# ['01.txt', '02.txt', '03.txt', '04.txt']

# %% [markdown]
# ## 연습문제 2

# %%
os.listdir('06_data')
# Out:
# ['01.pdf',
#  '01.txt',
#  '02.pdf',
#  '02.txt',
#  '03.pdf',
#  '03.txt',
#  '04.pdf',
#  '04.txt']

# %%
[i.replace('.txt', '.out') for i in os.listdir('06_data')] # 내 코드
# Out:
# ['01.pdf',
#  '01.out',
#  '02.pdf',
#  '02.out',
#  '03.pdf',
#  '03.out',
#  '04.pdf',
#  '04.out']

# %%
[re.sub('[.]txt$', '.out', i)
    for i in os.listdir(os.getcwd() + '\\06_data')]
# Out:
# ['01.pdf',
#  '01.out',
#  '02.pdf',
#  '02.out',
#  '03.pdf',
#  '03.out',
#  '04.pdf',
#  '04.out']

# %%
[re.sub('.txt', '.out', i) for i in os.listdir('06_data')]
# Out:
# ['01.pdf',
#  '01.out',
#  '02.pdf',
#  '02.out',
#  '03.pdf',
#  '03.out',
#  '04.pdf',
#  '04.out']

# %% [markdown]
# ## 문자열 prefixer

# %%
print('c:\nbc\nbc')
print('c:\\nbc\\nbc')
# Out:
# c:
# bc
# bc
# c:\nbc\nbc

# %% [markdown]
# prefixer `r(R)`을 붙여주면 \를 자동으로 \\\로 인식하게 만들어준다.

# %%
print(r'c:\nbc\nbc')
r'c:\nbc\nbc'
# Out:
# c:\nbc\nbc
# 'c:\\nbc\\nbc'

# %%
print(R'c:\nbc\nbc')
R'c:\nbc\nbc'
# Out:
# c:\nbc\nbc
# 'c:\\nbc\\nbc'

# %% [markdown]
# ## 경로명 사용 방법
# \가 이스케이프 문자가 아니면 자동으로 두 개 처리된다.

# %%
'c:\abc\kleist'
# Out:
# 'c:\x07bc\\kleist'

# %%
'c:\bc\kleist'
# Out:
# 'c:\x08c\\kleist'

# %%
'c:\c\kleist'
# Out:
# 'c:\\c\\kleist'

# %%
'c:\Users\kleist'
# Out:
#   Cell In[35], line 1
#     'c:\Users\kleist'
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
'c:\\abc\\kleist'
# Out:
# 'c:\\abc\\kleist'

# %%
'c:\\Users\\kleist'
# Out:
# 'c:\\Users\\kleist'

# %%
r'c:\abc\kleist'
# Out:
# 'c:\\abc\\kleist'

# %%
R'c:\Users\kleist'
# Out:
# 'c:\\Users\\kleist'

# %%
'c:/Users/kleist'
# Out:
# 'c:/Users/kleist'

# %%
os.getcwd()
# Out:
# 'c:\\Users\\yunji\\Desktop\\코퍼스언어학\\실습'

# %%
os.chdir(r'c:\Users\yunji\Desktop\코퍼스언어학\실습\06_data')

# %%
os.getcwd()
# Out:
# 'c:\\Users\\yunji\\Desktop\\코퍼스언어학\\실습\\06_data'

# %% [markdown]
# ## 폴더 생성 및 삭제

# %%
os.chdir(r'c:\Users\yunji\Desktop\코퍼스언어학\실습')
os.mkdir('out')
os.rmdir('out')
# os.listdir()

# %%
os.mkdir('.out/txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 os.mkdir('.out/txt')
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '.out/txt'

# %%
os.makedirs('./out/txt')

# %%
os.listdir('./out')
# Out:
# ['txt']

# %%
os.makedirs('./out/txt')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 os.makedirs('./out/txt')
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: './out/txt'

# %%
os.makedirs('./out/txt', exist_ok=True)
os.listdir('./out')
# Out:
# ['txt']

# %% [markdown]
# ## 연습문제 3

# %%
import os, re

txts = [txt for txt in os.listdir('06_data') if txt.endswith('.txt')];
final = []
for txt in txts:
    word = open('06_data/' + txt, 'r').read().split()
    final.extend([i for i in re.sub('^\W+|\W+$', '', word) if i.istitle()])
final
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 7
#       5 for txt in txts:
#       6     word = open('06_data/' + txt, 'r').read().split()
# ----> 7     final.extend([i for i in re.sub('^\W+|\W+$', '', word) if i.istitle()])
#       8 final
#
# File c:\Users\yunji\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:185, in sub(pattern, repl, string, count, flags)
#     178 def sub(pattern, repl, string, count=0, flags=0):
#     179     """Return the string obtained by replacing the leftmost
#     180     non-overlapping occurrences of the pattern in string by the
#     181     replacement repl.  repl can be either a string or a callable;
#     182     if a string, backslash escapes in it are processed.  If it is
#     183     a callable, it's passed the Match object and must return
#     184     a replacement string to be used."""
# ...

# %% [markdown]
# 1. `[06_out]` 폴더 만들기
# 2. `[06_data]` 폴더 파일 중, .txt 파일만 불러오기
# 3. 각 파일의 텍스트를 어휘 단위로 분리하기(공백 문자 연쇄 기준으로).
# 4. 어휘 앞뒤의 문장부호 하나 이상 연쇄 제거하기
# 5. 첫 문자가 대문자인 어휘만 추출하여 오름차순으로 정렬하기
# 6. 확장자를 out으로 변경하여, 5의 처리 결과를 하나의 라인에 하나의 어휘로 `[06_out]` 폴더에 출력하기

# %%
os.mkdir('06_data/06_out')

# %%
txts = [i for i in os.listdir('06_data') if i.endswith('.txt')]; txts
# Out:
# ['01.txt', '02.txt', '03.txt', '04.txt']

# %%
words = list()
num = 0
for txt in txts:
    words.append(open('06_data/' + txt).read().split())

    final = [i.strip('.,"\'') for i in words[num] if i.istitle()]
    final.sort()
    num += 1
    open('06_data/06_out/0' + str(num) + '.out', 'w').write('\n'.join(final))

# %%
# 교수님 답안
import os, re

os.chdir(r'c:\Users\yunji\Desktop\코퍼스언어학\실습')

os.makedirs('06_out', exist_ok=True)
a = os.listdir('./06_data')

for i in a:
    if i.endswith('.txt'):
        f = open('/'.join([os.getcwd(), '06_data', i])).read().split()
        t = [s for k in f if(s := re.sub('^\W+|\W+$', '', k)).istitle()]
        # t = [s for k in f if (s := re.sub('^[\W_]+|[\W_]+$', '', k)).istitle()]
        t.sort()
        open('./06_out/' + i.replace('.txt', '.out'), 'w').write('\n'.join(t))
